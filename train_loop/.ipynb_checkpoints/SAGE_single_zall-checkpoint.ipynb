# %%
import torch, pickle, time, os, random
from sklearn.model_selection import train_test_split
import numpy as np
import os.path as osp
import matplotlib.pyplot as plt
import torch_geometric as tg
from torch_geometric.loader import DataLoader
# accelerate huggingface to GPU
if torch.cuda.is_available():
    from accelerate import Accelerator
    accelerator = Accelerator()
    device = accelerator.device

torch.manual_seed(42)
random.seed(42)

# %%
os.listdir(osp.expanduser('~/../../../scratch/gpfs/cj1223/GraphStorage/'))
# Out:
# ['vlarge_all_4t_z1.0_standard_quant',
#  'vlarge_all_4t_z1.0_quantile_raw',
#  'vlarge_all_4t_z2.0_standard_quant',
#  'vlarge_all_4t_z2.0_None',
#  'redshift_scan_0',
#  'testid_all_4t_z2.0_None',
#  'vlarge_all_4t_z0.0_quantile_stand',
#  'vlarge_all_multi_try1',
#  'vlarge_all_4t_z2.0_quantile_raw',
#  'vlarge_all_4t_z0.0_standard_quant',
#  'vlarge_all_4t_z0.5_quantile_quant',
#  'vlarge_all_4t_z2.0_quantile_stand',
#  'vlarge_all_4t_z1.0_quantile_quant',
#  'transformers',
#  'vlarge_all_4t_z0.0_standard_raw',
#  'vlarge_all_4t_z0.5_standard_stand',
#  'vlarge_all_4t_z0.5_standard_quant',
#  'vlarge_all_4t_z0.0_quantile_raw',
#  'old',
#  'vlarge_all_4t_z1.0_None',
#  'vlarge_all_4t_z1.0_standard_stand',
#  'vlarge_all_4t_z2.0_standard_raw',
#  'testid_all_4t_z0.0_None',
#  'vlarge_all_4t_z0.5_standard_raw',
#  'vlarge_all_4t_z0.0_None',
#  'vlarge_all_4t_z0.5_quantile_raw',
#  'vlarge_all_4t_z1.0_standard_raw',
#  'vlarge_all_smass',
#  'vlarge_all_4t_z0.0_quantile_quant',
#  'vlarge_all_4t_z0.5_quantile_stand',
#  'vlarge_all_4t_zall_quantile_raw',
#  'vlarge_all_4t_z0.0_standard_stand',
#  'vlarge_all_4t_z1.0_quantile_stand',
#  'vlarge_all_4t_z2.0_quantile_quant',
#  'vlarge_all_4t_z2.0_standard_stand',
#  'vlarge_all_4t_z0.5_None']

# %%
case='vlarge_all_smass_z0.0_quantile_quant'
case='vlarge_all_smass'
case='vlarge_all_4t_zall_quantile_raw'


datatraint=pickle.load(open(osp.expanduser(f'~/../../../scratch/gpfs/cj1223/GraphStorage/{case}/data_train.pkl'), 'rb'))
datatestt=pickle.load(open(osp.expanduser(f'~/../../../scratch/gpfs/cj1223/GraphStorage/{case}/data_test.pkl'), 'rb'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_10065/2819419852.py in <module>
#       5
#       6 datatraint=pickle.load(open(osp.expanduser(f'~/../../../scratch/gpfs/cj1223/GraphStorage/{case}/data_train.pkl'), 'rb'))
# ----> 7 datatestt=pickle.load(open(osp.expanduser(f'~/../../../scratch/gpfs/cj1223/GraphStorage/{case}/data_test.pkl'), 'rb'))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/cj1223/../../../scratch/gpfs/cj1223/GraphStorage/vlarge_all_4t_zall_quantile_raw/data_test.pkl'

# %%
from torch_geometric.data import Data
train_data=[]
for d in datatraint:
    train_data.append(Data(x=d.x, edge_index=d.edge_index, edge_attr=d.edge_attr, y=d.y[[0]]))

# %%
from torch_geometric.data import Data
test_data=[]
for d in datatestt:
    test_data.append(Data(x=d.x, edge_index=d.edge_index, edge_attr=d.edge_attr, y=d.y[[0]]))

# %%
try:
    n_targ=len(data[0].y)
except:
    n_targ=1
n_feat=len(data[0].x[0])
n_feat, n_targ
# Out:
# (43, 1)

# %%
from torch import nn
class MLP(nn.Module):
    def __init__(self, n_in, n_out, hidden=64, nlayers=2, layer_norm=True):
        super().__init__()
        layers = [nn.Linear(n_in, hidden), nn.ReLU()]
        for i in range(nlayers):
            layers.append(nn.Linear(hidden, hidden))
            layers.append(nn.ReLU()) 
        if layer_norm:
            layers.append(nn.LayerNorm(hidden))
        layers.append(nn.Linear(hidden, n_out))
        self.mlp = nn.Sequential(*layers)

    def forward(self, x):
        return self.mlp(x)

# %%
import torch.nn.functional as F
from torch.nn import Linear, BatchNorm1d, LayerNorm
from torch_geometric.nn import SAGEConv, global_mean_pool, norm, global_max_pool, global_add_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels, nlin=3):
        super(GCN, self).__init__()
        self.node_enc = MLP(n_feat, hidden_channels, layer_norm=True)
        
        self.conv1 = SAGEConv(hidden_channels, hidden_channels) 
        
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.conv3 = SAGEConv(hidden_channels, hidden_channels)
        self.conv4 = SAGEConv(hidden_channels, hidden_channels)
        self.conv5 = SAGEConv(hidden_channels, hidden_channels)
        
        self.lin = Linear(2*hidden_channels, hidden_channels)
        self.norm = LayerNorm(normalized_shape=hidden_channels) # layer_norm instead
        self.lin_f = Linear(hidden_channels, n_targ)
        
    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.node_enc(x)
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)
        x = x.relu()
        x = self.conv4(x, edge_index)
        x = x.relu()
        x = self.conv5(x, edge_index)
        x = x.relu()
#         x = global_add_pool(x, batch)
        x = torch.cat([global_max_pool(x, batch),global_add_pool(x, batch)], 1)  ## Miles says use sumpool

        x = self.lin(x)
        x = x.relu()
        x = self.lin_f(self.norm(x))
#         x=self.lin1(x)
        return x
    
model = GCN(hidden_channels=64)
next(model.parameters()).is_cuda ##check number one
# Out:
# False

# %%
criterion = torch.nn.MSELoss()
# criterion = torch.nn.L1Loss()
# criterion = torch.nn.SmoothL1Loss(beta=0.3)


n_epochs=200
n_trials=1
batch_size=128
split=0.8
# test_data=data[int(len(data)*split):]
# train_data=data[:int(len(data)*split)]
# train_data, test_data=train_test_split(data, test_size=0.2)

l1_lambda = 0
l2_lambda = 0

# %%
trains, tests, scatter = [], [], []
yss, preds=[],[]
model = GCN(hidden_channels=128)
train_loader=DataLoader(train_data, batch_size=batch_size, shuffle=1, num_workers=4)
test_loader=DataLoader(test_data, batch_size=batch_size, shuffle=0,num_workers=4)    
optimizer = torch.optim.Adam(model.parameters(), lr=0.003)
_, _, test_loader = accelerator.prepare(model, optimizer, test_loader)
model, optimizer, train_loader = accelerator.prepare(model, optimizer, train_loader)
print('GPU ', next(model.parameters()).is_cuda)
# Initialize our train function
def train():
    model.train()
    
    for data in train_loader:  
        out = model(data.x, data.edge_index, data.batch)  
        loss = criterion(out, data.y.view(-1,n_targ)) 
        l1_norm = sum(p.abs().sum() for p in model.parameters())
        l2_norm = sum(p.pow(2.0).sum() for p in model.parameters())


        loss = loss + l1_lambda * l1_norm + l2_lambda * l2_norm
#             loss.backward()
        accelerator.backward(loss)
        optimizer.step() 
        optimizer.zero_grad() 
#     print(loss, l1_norm*l1_lambda, l2_norm*l2_lambda)
 # test function

def test(loader): ##### transform back missing
    model.eval()
    outs = []
    ys = []
    with torch.no_grad(): ##this solves it!!!
        for dat in loader: 
            out = model(dat.x, dat.edge_index, dat.batch) 
            ys.append(dat.y.view(-1,n_targ))
            outs.append(out)
    outss=torch.vstack(outs)
    yss=torch.vstack(ys)
    return torch.std(outss - yss, axis=0), outss, yss
# Out:
# GPU  True

# %%
#this uses about 1 GB of memory on the GPU
tr_acc, te_acc = [], []
start=time.time()
for epoch in range(n_epochs):

    train()

    if (epoch+1)%2==0:
        train_acc, _ , _ = test(train_loader)
        test_acc, _ , _ = test(test_loader)
        tr_acc.append(train_acc.cpu())
        te_acc.append(test_acc.cpu())
        print(f'Epoch: {epoch+1:03d}, Train scatter: {np.round(train_acc.cpu().numpy(), 4)} \n \
        Test scatter: {np.round(test_acc.cpu().numpy(), 4)}')
stop=time.time()
spent=stop-start
print(f"{spent:.2f} seconds spent training, {spent/n_epochs:.3f} seconds per epoch. Processed {len(data)*split*n_epochs/spent:.0f} trees per second")
# Out:
# Epoch: 002, Train scatter: [0.8681]
#          Test scatter: [0.8681]
# Epoch: 004, Train scatter: [0.8437]
#          Test scatter: [0.8437]
# Epoch: 006, Train scatter: [0.8006]
#          Test scatter: [0.8006]
# Epoch: 008, Train scatter: [0.7144]
#          Test scatter: [0.7144]
# Epoch: 010, Train scatter: [0.5694]
#          Test scatter: [0.5694]
# Epoch: 012, Train scatter: [0.4509]
#          Test scatter: [0.4509]
# Epoch: 014, Train scatter: [0.3547]
#          Test scatter: [0.3547]
# Epoch: 016, Train scatter: [0.3345]
#          Test scatter: [0.3345]
# Epoch: 018, Train scatter: [0.3301]
#          Test scatter: [0.3301]
# Epoch: 020, Train scatter: [0.3176]
#          Test scatter: [0.3176]
# Epoch: 022, Train scatter: [0.3112]
#          Test scatter: [0.3112]
# Epoch: 024, Train scatter: [0.3108]
#          Test scatter: [0.3108]
# Epoch: 026, Train scatter: [0.3038]
#          Test scatter: [0.3038]
# Epoch: 028, Train scatter: [0.2989]
#          Test scatter: [0.2989]
# Epoch: 030, Train scatter: [0.2965]
#          Test scatter: [0.2965]
# Epoch: 032, Train scatter: [0.2987]
#          Test scatter: [0.2987]
# Epoch: 034, Train scatter: [0.3009]
#          Test scatter: [0.3009]
# Epoch: 036, Train scatter: [0.294]
#          Test scatter: [0.294]
# Epoch: 038, Train scatter: [0.3175]
#          Test scatter: [0.3175]
# Epoch: 040, Train scatter: [0.2874]
#          Test scatter: [0.2874]
# Epoch: 042, Train scatter: [0.2822]
#          Test scatter: [0.2822]
# Epoch: 044, Train scatter: [0.2852]
#          Test scatter: [0.2852]
# Epoch: 046, Train scatter: [0.2883]
#          Test scatter: [0.2883]
# Epoch: 048, Train scatter: [0.2776]
#          Test scatter: [0.2776]
# Epoch: 050, Train scatter: [0.2862]
#          Test scatter: [0.2862]
# Epoch: 052, Train scatter: [0.2704]
#          Test scatter: [0.2704]
# Epoch: 054, Train scatter: [0.2695]
#          Test scatter: [0.2695]
# Epoch: 056, Train scatter: [0.268]
#          Test scatter: [0.268]
# Epoch: 058, Train scatter: [0.2783]
#          Test scatter: [0.2783]
# Epoch: 060, Train scatter: [0.2609]
#          Test scatter: [0.2609]
# Epoch: 062, Train scatter: [0.2591]
#          Test scatter: [0.2591]
# Epoch: 064, Train scatter: [0.2627]
#          Test scatter: [0.2627]
# Epoch: 066, Train scatter: [0.2757]
#          Test scatter: [0.2757]
# Epoch: 068, Train scatter: [0.2603]
#          Test scatter: [0.2603]
# Epoch: 070, Train scatter: [0.2483]
#          Test scatter: [0.2483]
# Epoch: 072, Train scatter: [0.244]
#          Test scatter: [0.244]
# Epoch: 074, Train scatter: [0.2364]
#          Test scatter: [0.2364]
# Epoch: 076, Train scatter: [0.254]
#          Test scatter: [0.254]
# Epoch: 078, Train scatter: [0.2589]
#          Test scatter: [0.2589]
# Epoch: 080, Train scatter: [0.2357]
#          Test scatter: [0.2357]
# Epoch: 082, Train scatter: [0.22]
#          Test scatter: [0.22]
# Epoch: 084, Train scatter: [0.2135]
#          Test scatter: [0.2135]
# Epoch: 086, Train scatter: [0.2113]
#          Test scatter: [0.2113]
# Epoch: 088, Train scatter: [0.2287]
#          Test scatter: [0.2287]
# Epoch: 090, Train scatter: [0.2055]
#          Test scatter: [0.2055]
# Epoch: 092, Train scatter: [0.205]
#          Test scatter: [0.205]
# Epoch: 094, Train scatter: [0.1964]
#          Test scatter: [0.1964]
# Epoch: 096, Train scatter: [0.194]
#          Test scatter: [0.194]
# Epoch: 098, Train scatter: [0.1926]
#          Test scatter: [0.1926]
# Epoch: 100, Train scatter: [0.1857]
#          Test scatter: [0.1857]
# Epoch: 102, Train scatter: [0.1807]
#          Test scatter: [0.1807]
# Epoch: 104, Train scatter: [0.1739]
#          Test scatter: [0.1739]
# Epoch: 106, Train scatter: [0.1992]
#          Test scatter: [0.1992]
# Epoch: 108, Train scatter: [0.193]
#          Test scatter: [0.193]
# Epoch: 110, Train scatter: [0.1756]
#          Test scatter: [0.1756]
# Epoch: 112, Train scatter: [0.1624]
#          Test scatter: [0.1624]
# Epoch: 114, Train scatter: [0.1525]
#          Test scatter: [0.1525]
# Epoch: 116, Train scatter: [0.1693]
#          Test scatter: [0.1693]
# Epoch: 118, Train scatter: [0.164]
#          Test scatter: [0.164]
# Epoch: 120, Train scatter: [0.1641]
#          Test scatter: [0.1641]
# Epoch: 122, Train scatter: [0.1714]
#          Test scatter: [0.1714]
# Epoch: 124, Train scatter: [0.1474]
#          Test scatter: [0.1474]
# Epoch: 126, Train scatter: [0.1479]
#          Test scatter: [0.1479]
# Epoch: 128, Train scatter: [0.1597]
#          Test scatter: [0.1597]
# Epoch: 130, Train scatter: [0.1471]
#          Test scatter: [0.1471]
# Epoch: 132, Train scatter: [0.1537]
#          Test scatter: [0.1537]
# Epoch: 134, Train scatter: [0.149]
#          Test scatter: [0.149]
# Epoch: 136, Train scatter: [0.1432]
#          Test scatter: [0.1432]
# Epoch: 138, Train scatter: [0.1403]
#          Test scatter: [0.1403]
# Epoch: 140, Train scatter: [0.1588]
#          Test scatter: [0.1588]
# Epoch: 142, Train scatter: [0.1252]
#          Test scatter: [0.1252]
# Epoch: 144, Train scatter: [0.1276]
#          Test scatter: [0.1276]
# Epoch: 146, Train scatter: [0.1237]
#          Test scatter: [0.1237]
# Epoch: 148, Train scatter: [0.1212]
#          Test scatter: [0.1212]
# Epoch: 150, Train scatter: [0.117]
#          Test scatter: [0.117]
# Epoch: 152, Train scatter: [0.1135]
#          Test scatter: [0.1135]
# Epoch: 154, Train scatter: [0.1034]
#          Test scatter: [0.1034]
# Epoch: 156, Train scatter: [0.099]
#          Test scatter: [0.099]
# Epoch: 158, Train scatter: [0.0938]
#          Test scatter: [0.0938]
# Epoch: 160, Train scatter: [0.1045]
#          Test scatter: [0.1045]
# Epoch: 162, Train scatter: [0.1111]
#          Test scatter: [0.1111]
# Epoch: 164, Train scatter: [0.113]
#          Test scatter: [0.113]
# Epoch: 166, Train scatter: [0.1091]
#          Test scatter: [0.1091]
# Epoch: 168, Train scatter: [0.1079]
#          Test scatter: [0.1079]
# Epoch: 170, Train scatter: [0.0916]
#          Test scatter: [0.0916]
# Epoch: 172, Train scatter: [0.0988]
#          Test scatter: [0.0988]
# Epoch: 174, Train scatter: [0.0885]
#          Test scatter: [0.0885]
# Epoch: 176, Train scatter: [0.0885]
#          Test scatter: [0.0885]
# Epoch: 178, Train scatter: [0.0844]
#          Test scatter: [0.0844]
# Epoch: 180, Train scatter: [0.0978]
#          Test scatter: [0.0978]
# Epoch: 182, Train scatter: [0.0839]
#          Test scatter: [0.0839]
# Epoch: 184, Train scatter: [0.0908]
#          Test scatter: [0.0908]
# Epoch: 186, Train scatter: [0.0997]
#          Test scatter: [0.0997]
# Epoch: 188, Train scatter: [0.0849]
#          Test scatter: [0.0849]
# Epoch: 190, Train scatter: [0.0891]
#          Test scatter: [0.0891]
# Epoch: 192, Train scatter: [0.0913]
#          Test scatter: [0.0913]
# Epoch: 194, Train scatter: [0.1122]
#          Test scatter: [0.1122]
# Epoch: 196, Train scatter: [0.1025]
#          Test scatter: [0.1025]
# Epoch: 198, Train scatter: [0.0841]
#          Test scatter: [0.0841]
# Epoch: 200, Train scatter: [0.079]
#          Test scatter: [0.079]
# 440.30 seconds spent training, 2.201 seconds per epoch. Processed 1177 trees per second

# %%
print(f'{np.round(train_acc.cpu().numpy(), 4)}')
# Out:
# [0.079]

# %%
tr, te =[], []

for tra, tes in zip(tr_acc, te_acc):
    tr.append(tra.cpu().numpy())
    te.append(tes.cpu().numpy())

# %%
from scipy.ndimage import gaussian_filter as gf
plt.plot(gf(np.array(tr), 2))
plt.plot(gf(np.array(te), 2))

# %%
teststd, outtest, ytest = test(test_loader)
pred=outtest.cpu().numpy()
ys=ytest.cpu().numpy()
# Out:
# /home/cj1223/.conda/envs/juptorch/lib/python3.9/site-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 1, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
fig , ax = plt.subplots(1, figsize=(10,6))
l=0
for k in range(n_targ):
#     ax[k].hist(outtest.cpu().numpy()[:,k]-ytest.cpu().numpy()[:,k], bins=1000, histtype='step', label='res')
    ax.hist(pred[:,k], bins=50, range=list(np.percentile(outtest.cpu().numpy()[:,k], [l,100-l])), histtype='step', label='pred')
    ax.hist(ytest.cpu().numpy()[:,k], bins=50, range=list(np.percentile(outtest.cpu().numpy()[:,k], [l,100-l])),histtype='step', label='true')
    ax.legend()
#     print(np.std(ress.cpu().numpy()[:,k]), np.mean(ress.cpu().numpy()[:,k]))

# %%
fig , ax = plt.subplots(1,1, figsize=(10,10))
yte=ys
predte=pred
ax.plot(yte, predte, 'ro', alpha=0.2)
ax.plot([min(yte),max(yte)],[min(yte),max(yte)], 'k--', label='Perfect correspondance')
ax.set(title=[f'Stellar mass after {epoch} epochs', np.round(np.std(yte-predte),3), np.round(np.mean(yte-predte),2)], xlabel='True [dex]', ylabel='Predicted [dex]')
ax.legend()

# %%
transform='quantile'
transform_path=osp.expanduser(f"~/../../../scratch/gpfs/cj1223/GraphStorage/transformers/{transform}_alltarg_1.pkl")
target_scaler=pickle.load(open(transform_path, 'rb'))

transform_path=osp.expanduser(f"~/../../../scratch/gpfs/cj1223/GraphStorage/transformers/{transform}_allfeat_1.pkl")
feat_scaler=pickle.load(open(transform_path, 'rb'))

# %%
fig , ax = plt.subplots(1,1, figsize=(10,10))
yte=np.hstack(target_scaler[8].inverse_transform(ys.reshape(-1,1)))
predte=np.hstack(target_scaler[8].inverse_transform(pred.reshape(-1,1)))
ax.plot(yte, predte, 'ro', alpha=0.2)
ax.plot([min(yte),max(yte)],[min(yte),max(yte)], 'k--', label='Perfect correspondance')
ax.set(title=[f'Stellar mass after {epoch} epochs', np.round(np.std(yte-predte),2), np.round(np.mean(yte-predte),2)], xlabel='True [dex]', ylabel='Predicted [dex]')
ax.legend()
