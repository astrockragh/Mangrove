# %%
import matplotlib.pyplot as plt
import numpy as np
from torch_geometric.datasets import KarateClub
dataset = KarateClub()
# this torch.geometric.datasets object comprises of edge(edge information for each node), x(nodes) 
#and y(labels for each node)
x,edge,y, train_mask = dataset[0]
npx = x[1].numpy()
npy = y[1].numpy()
npe = edge[1].numpy()

# %%
import networkx as nx

g = nx.Graph()

name,edgeinfo = edge

src = edgeinfo[0].numpy()
dst = edgeinfo[1].numpy()
edgelist = zip(src,dst)
g.add_nodes_from(range(34))
# for i,j in edgelist:
#     g.add_edge(i,j) 

nx.draw(g)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/networkx/utils/decorators.py in _random_state(func, *args, **kwargs)
#     395         try:
# --> 396             random_state_arg = args[random_state_index]
#     397         except TypeError as e:
#
# IndexError: tuple index out of range
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-2-1eaf1f85dc69> in <module>
#      12 #     g.add_edge(i,j)
#      13
# ---> 14 nx.draw(g)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/networkx/drawing/nx_pylab.py in draw(G, pos, ax, **kwds)
#     121         kwds["with_labels"] = "labels" in kwds
#     122
# --> 123     draw_networkx(G, pos=pos, ax=ax, **kwds)
#     124     ax.set_axis_off()
# ...

# %%
dataset[0]
# Out:
# Data(x=[34, 34], edge_index=[2, 156], y=[34], train_mask=[34])
