# %%
import torch, pickle, time, os, random
import numpy as np
import matplotlib.pyplot as plt
import torch_geometric as tg
from torch_geometric.loader import DataLoader
# accelerate huggingface to GPU
if torch.cuda.is_available():
    from accelerate import Accelerator
    accelerator = Accelerator()
    device = accelerator.device

torch.manual_seed(42)
random.seed(42)

# %%
os.listdir('../../../../scratch/gpfs/cj1223/GraphStorage/')
# Out:
# ['medium_beforeafter',
#  'medium_redshift_50_all',
#  'test_onlyhmass_smass',
#  'medium_redshift_80_all',
#  'test_cut',
#  'medium_all_q_diffbeforeafter',
#  'medium_all_smass',
#  'medium_onlyhmass_smass',
#  'medium_scaleonly_smass',
#  'test_beforeafter',
#  'test_all_smass',
#  'medium_redshift_15_all',
#  'transformers',
#  'medium_all_variance',
#  'medium_redshift_1_all',
#  'medium_all_q',
#  'medium_redshift_10_all',
#  'medium_all_final',
#  'test_variance',
#  'small_all_q_variancehalomass',
#  'medium_all_residual',
#  'medium_all',
#  'test',
#  'test_final',
#  'med_all_residual',
#  'medium_redshift_25_all',
#  'one_all_q',
#  'test_redshift_scan',
#  'medium_all_finalhalo',
#  '105lim_all_smass',
#  'medium_redshift_5_all',
#  'small_all_q',
#  'testpy',
#  'medium_noinfo_smass',
#  'medium_hmassonly_smass']

# %%
# case='medium_hmassonly_smass'
# case='medium_scaleonly_smass'
### this didn't work as well as I initially thought, must have done something wrong, but still better than base
# case='medium_onlyedge_smass' 
# case='medium_noinfo_smass' 


data=pickle.load(open(f'../../../../scratch/gpfs/cj1223/GraphStorage/{case}/data.pkl', 'rb'))

# %%
len(np.array([data[0].y]))
# Out:
# 1

# %%
import torch.nn.functional as F
from torch.nn import Linear, BatchNorm1d, LayerNorm
from torch_geometric.nn import SAGEConv, global_mean_pool, norm, global_max_pool, global_add_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels, nlin=3):
        super(GCN, self).__init__()
        
        self.conv1 = SAGEConv(data[0].num_node_features, hidden_channels) ##use meta-layer
        ## https://pytorch-geometric.readthedocs.io/en/latest/modules/nn.html#torch_geometric.nn.meta.MetaLayer
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.conv3 = SAGEConv(hidden_channels, hidden_channels)
        self.conv4 = SAGEConv(hidden_channels, hidden_channels)
        self.conv5 = SAGEConv(hidden_channels, hidden_channels)
        
        
        # Our final linear layer will define our output
        self.norm = LayerNorm(normalized_shape=hidden_channels) # layer_norm instead
        self.lin1 = Linear(hidden_channels, 1)
        
    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)
        x = x.relu()
        x = self.conv4(x, edge_index)
        x = x.relu()
        x = self.conv5(x, edge_index)
        x = x.relu()
        x = global_add_pool(x, batch)  ## Miles says use sumpool

        x = self.lin1(self.norm(x))
#         x=self.lin1(x)
        return x
    
model = GCN(hidden_channels=32)
next(model.parameters()).is_cuda ##check number one
# Out:
# False

# %%
criterion = torch.nn.MSELoss()
n_epochs=200
n_trials=1
batch_size=128
split=0.8
test_data=data[int(len(data)*split):]
train_data=data[:int(len(data)*split)]

# %%
trains, tests, scatter = [], [], []
yss, preds=[],[]
for _ in range(n_trials):
    model = GCN(hidden_channels=32)
    train_loader=DataLoader(train_data, batch_size=batch_size, shuffle=1)
    test_loader=DataLoader(test_data, batch_size=batch_size, shuffle=1)    
    optimizer = torch.optim.Adam(model.parameters(), lr=0.003)
    _, _, test_loader = accelerator.prepare(model, optimizer, test_loader)
    model, optimizer, train_loader = accelerator.prepare(model, optimizer, train_loader)
    print('GPU ', next(model.parameters()).is_cuda)
    # Initialize our train function
    def train():
        model.train()

        for data in train_loader:  
            out = model(data.x, data.edge_index, data.batch)  
            loss = criterion(out, data.y.view(-1,1)) 
#             loss.backward()
            accelerator.backward(loss)
            optimizer.step() 
            optimizer.zero_grad() 
     # test function
    def test(loader):
        model.eval()

        correct = 0
        for dat in loader: 
            out = model(dat.x, dat.edge_index, dat.batch) 
    #         print(out)
            correct += (torch.square(out - dat.y.view(-1,1))).sum() 
        return correct / len(loader.dataset) 
    tr_acc, te_acc=[],[]
    start=time.time()
    for epoch in range(n_epochs):
        train()

        if (epoch+1)%2==0:
            train_acc = test(train_loader).cpu().detach().numpy()
            test_acc = test(test_loader).cpu().detach().numpy()
            tr_acc.append(np.sqrt(train_acc))
            te_acc.append(np.sqrt(test_acc))
            print(f'Epoch: {epoch+1:03d}, Train scatter: {np.sqrt(train_acc):.4f}, Test scatter: {np.sqrt(test_acc):.4f}')
    stop=time.time()
    spent=stop-start
    tests.append(te_acc)
    trains.append(tr_acc)
    print(f"{spent:.2f} seconds spent training, {spent/n_epochs:.3f} seconds per epoch. Processed {len(data)*split*n_epochs/spent:.0f} trees per second")
    ys, pred=[],[]
    def test(loader):
        model.eval()

        correct = 0
        for dat in loader: 
            out = model(dat.x, dat.edge_index, dat.batch) 
            pred.append(out.view(1,-1).cpu().detach().numpy())
            ys.append(np.array(dat.y.cpu())) 
    test(test_loader)
    ys=np.hstack(ys)
    pred=np.hstack(pred)[0]
    scatter.append(np.std(ys-pred))
    yss.append(ys)
    preds.append(pred)
# Out:
# GPU  True
# Epoch: 002, Train scatter: 0.2223, Test scatter: 0.2204
# Epoch: 004, Train scatter: 0.2257, Test scatter: 0.2242
# Epoch: 006, Train scatter: 0.2178, Test scatter: 0.2179
# Epoch: 008, Train scatter: 0.2058, Test scatter: 0.2042
# Epoch: 010, Train scatter: 0.2084, Test scatter: 0.2080
# Epoch: 012, Train scatter: 0.1990, Test scatter: 0.1974
# Epoch: 014, Train scatter: 0.1984, Test scatter: 0.1973
# Epoch: 016, Train scatter: 0.1958, Test scatter: 0.1953
# Epoch: 018, Train scatter: 0.1985, Test scatter: 0.1970
# Epoch: 020, Train scatter: 0.1972, Test scatter: 0.1975
# Epoch: 022, Train scatter: 0.1974, Test scatter: 0.1975
# Epoch: 024, Train scatter: 0.1936, Test scatter: 0.1922
# Epoch: 026, Train scatter: 0.1947, Test scatter: 0.1938
# Epoch: 028, Train scatter: 0.1923, Test scatter: 0.1917
# Epoch: 030, Train scatter: 0.1972, Test scatter: 0.1975
# Epoch: 032, Train scatter: 0.1963, Test scatter: 0.1952
# Epoch: 034, Train scatter: 0.1959, Test scatter: 0.1947
# Epoch: 036, Train scatter: 0.1906, Test scatter: 0.1902
# Epoch: 038, Train scatter: 0.1975, Test scatter: 0.1989
# Epoch: 040, Train scatter: 0.1916, Test scatter: 0.1930
# Epoch: 042, Train scatter: 0.1876, Test scatter: 0.1886
# Epoch: 044, Train scatter: 0.1877, Test scatter: 0.1890
# Epoch: 046, Train scatter: 0.1888, Test scatter: 0.1904
# Epoch: 048, Train scatter: 0.1902, Test scatter: 0.1921
# Epoch: 050, Train scatter: 0.1922, Test scatter: 0.1928
# Epoch: 052, Train scatter: 0.1932, Test scatter: 0.1952
# Epoch: 054, Train scatter: 0.1953, Test scatter: 0.1986
# Epoch: 056, Train scatter: 0.1870, Test scatter: 0.1905
# Epoch: 058, Train scatter: 0.1922, Test scatter: 0.1969
# Epoch: 060, Train scatter: 0.1853, Test scatter: 0.1887
# Epoch: 062, Train scatter: 0.1917, Test scatter: 0.1944
# Epoch: 064, Train scatter: 0.1842, Test scatter: 0.1881
# Epoch: 066, Train scatter: 0.2102, Test scatter: 0.2152
# Epoch: 068, Train scatter: 0.1843, Test scatter: 0.1904
# Epoch: 070, Train scatter: 0.1913, Test scatter: 0.1960
# Epoch: 072, Train scatter: 0.1867, Test scatter: 0.1931
# Epoch: 074, Train scatter: 0.1856, Test scatter: 0.1913
# Epoch: 076, Train scatter: 0.1839, Test scatter: 0.1906
# Epoch: 078, Train scatter: 0.1843, Test scatter: 0.1940
# Epoch: 080, Train scatter: 0.1898, Test scatter: 0.2031
# Epoch: 082, Train scatter: 0.1852, Test scatter: 0.1904
# Epoch: 084, Train scatter: 0.1847, Test scatter: 0.1975
# Epoch: 086, Train scatter: 0.1939, Test scatter: 0.2108
# Epoch: 088, Train scatter: 0.1808, Test scatter: 0.1971
# Epoch: 090, Train scatter: 0.1863, Test scatter: 0.1965
# Epoch: 092, Train scatter: 0.1839, Test scatter: 0.1987
# Epoch: 094, Train scatter: 0.1795, Test scatter: 0.1950
# Epoch: 096, Train scatter: 0.1825, Test scatter: 0.1981
# Epoch: 098, Train scatter: 0.1803, Test scatter: 0.1975
# Epoch: 100, Train scatter: 0.1861, Test scatter: 0.2035
# Epoch: 102, Train scatter: 0.1822, Test scatter: 0.1987
# Epoch: 104, Train scatter: 0.1793, Test scatter: 0.1998
# Epoch: 106, Train scatter: 0.1788, Test scatter: 0.2028
# Epoch: 108, Train scatter: 0.1957, Test scatter: 0.2100
# Epoch: 110, Train scatter: 0.1869, Test scatter: 0.2142
# Epoch: 112, Train scatter: 0.1790, Test scatter: 0.2024
# Epoch: 114, Train scatter: 0.1839, Test scatter: 0.2043
# Epoch: 116, Train scatter: 0.1783, Test scatter: 0.2011
# Epoch: 118, Train scatter: 0.1766, Test scatter: 0.2051
# Epoch: 120, Train scatter: 0.1762, Test scatter: 0.2019
# Epoch: 122, Train scatter: 0.1778, Test scatter: 0.2053
# Epoch: 124, Train scatter: 0.1775, Test scatter: 0.2092
# Epoch: 126, Train scatter: 0.1789, Test scatter: 0.2054
# Epoch: 128, Train scatter: 0.1796, Test scatter: 0.2085
# Epoch: 130, Train scatter: 0.1765, Test scatter: 0.2073
# Epoch: 132, Train scatter: 0.1848, Test scatter: 0.2115
# Epoch: 134, Train scatter: 0.1745, Test scatter: 0.2062
# Epoch: 136, Train scatter: 0.1748, Test scatter: 0.2106
# Epoch: 138, Train scatter: 0.1798, Test scatter: 0.2010
# Epoch: 140, Train scatter: 0.1768, Test scatter: 0.2115
# Epoch: 142, Train scatter: 0.1739, Test scatter: 0.2062
# Epoch: 144, Train scatter: 0.1829, Test scatter: 0.2161
# Epoch: 146, Train scatter: 0.1742, Test scatter: 0.2023
# Epoch: 148, Train scatter: 0.1752, Test scatter: 0.2033
# Epoch: 150, Train scatter: 0.1726, Test scatter: 0.2045
# Epoch: 152, Train scatter: 0.1739, Test scatter: 0.2080
# Epoch: 154, Train scatter: 0.1718, Test scatter: 0.2063
# Epoch: 156, Train scatter: 0.1712, Test scatter: 0.2026
# Epoch: 158, Train scatter: 0.1751, Test scatter: 0.2048
# Epoch: 160, Train scatter: 0.1738, Test scatter: 0.2087
# Epoch: 162, Train scatter: 0.1719, Test scatter: 0.2059
# Epoch: 164, Train scatter: 0.1859, Test scatter: 0.2193
# Epoch: 166, Train scatter: 0.1724, Test scatter: 0.2042
# Epoch: 168, Train scatter: 0.1763, Test scatter: 0.2129
# Epoch: 170, Train scatter: 0.1714, Test scatter: 0.2078
# Epoch: 172, Train scatter: 0.1799, Test scatter: 0.2142
# Epoch: 174, Train scatter: 0.1897, Test scatter: 0.2218
# Epoch: 176, Train scatter: 0.1691, Test scatter: 0.2060
# Epoch: 178, Train scatter: 0.1785, Test scatter: 0.2127
# Epoch: 180, Train scatter: 0.1714, Test scatter: 0.2106
# Epoch: 182, Train scatter: 0.1728, Test scatter: 0.2140
# Epoch: 184, Train scatter: 0.1677, Test scatter: 0.2073
# Epoch: 186, Train scatter: 0.1692, Test scatter: 0.2068
# Epoch: 188, Train scatter: 0.1732, Test scatter: 0.2149
# Epoch: 190, Train scatter: 0.1702, Test scatter: 0.2093
# Epoch: 192, Train scatter: 0.1683, Test scatter: 0.2073
# Epoch: 194, Train scatter: 0.1681, Test scatter: 0.2124
# Epoch: 196, Train scatter: 0.1673, Test scatter: 0.2052
# Epoch: 198, Train scatter: 0.1666, Test scatter: 0.2069
# Epoch: 200, Train scatter: 0.1671, Test scatter: 0.2101
# 389.89 seconds spent training, 1.949 seconds per epoch. Processed 8327 trees per second

# %%
np.mean(scatter), np.std(scatter)
# Out:
# (0.20940545, 0.0)

# %%
np.min(tests)
# Out:
# 0.18813275

# %%
plt.plot(tr_acc, label='train loss')
plt.plot(te_acc, label='test loss')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %%
ys, pred=[],[]
def test(loader):
    model.eval()
 
    correct = 0
    for dat in loader: 
        out = model(dat.x, dat.edge_index, dat.batch) 
        pred.append(out.view(1,-1).cpu().detach().numpy())
        ys.append(np.array(dat.y.cpu())) 
test(test_loader)
# test(train_loader)
ys=np.hstack(ys)
pred=np.hstack(pred)[0]

# %%
fig, ax= plt.subplots(2, figsize=(9,12))
bins=50
ax[0].hist(ys, bins=bins, range=(np.percentile(np.hstack([ys,pred]), [1,99])), label='true',  histtype='step')
ax[0].hist(pred, bins=bins, range=(np.percentile(np.hstack([ys,pred]), [1,99])), label='pred', histtype='step')
ax[1].hist((ys-pred), bins=bins,range=(np.percentile(ys-pred, [1,99])),  histtype='step', label='residuals');
ax[0].legend()
ax[1].legend()
ax[0].set(title='Predicted/true stellar mass', xlabel='log10(M_stellar)', ylabel='N')
ax[1].set(title=f'Residuals, scatter is {np.std(ys-pred):.3f}',xlabel='log10(M_stellar)_true-log10(M_stellar)_predicted', ylabel='N')
# Out:
# [Text(0.5, 1.0, 'Residuals, scatter is 0.293'),
#  Text(0.5, 0, 'log10(M_stellar)_true-log10(M_stellar)_predicted'),
#  Text(0, 0.5, 'N')]

# %%
fig, ax =plt.subplots(figsize=(12,9))
ax.plot(ys,pred, 'ro')
ax.plot([min(ys),max(ys)],[min(ys),max(ys)], 'k--', label='Perfect correspondance')
ax.set(xlabel='true',ylabel='predicted', title='True/predicted corr')
ax.legend()

# %%
fig, ax =plt.subplots(figsize=(12,9))
h = ax.hist2d(ys,pred, bins=50, range=[np.percentile(ys, [1,99]),np.percentile(pred, [1,99])])
fig.colorbar(h[3], ax=ax)
ax.plot([min(ys),max(ys)],[min(ys),max(ys)], 'k--', label='Perfect correspondance')
ax.set(xlabel='true',ylabel='predicted', title='True/predicted corr')
ax.legend()

# %%
x,y=[], []
for d in data:
    x.append(d.x[0,2].numpy())
    y.append(d.y.numpy())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_2141/3651939864.py in <module>
#       1 x,y=[], []
#       2 for d in data:
# ----> 3     x.append(d.x[0,2].numpy())
#       4     y.append(d.y.numpy())
#
# IndexError: index 2 is out of bounds for dimension 1 with size 1

# %%
plt.plot(x, y, 'o', markersize=1)

# %%
## remember to validate that test/val/train are actually comparable
## create toy problem (predict variance of all halo masses eg, verifying that in takes into account edges)
## same, predict average of the difference of post-merge halo and pre merger halos

## try different pools

# %%
xte, yte, lte = [], [], []
for d in test_data:
    xte.append(d.x.numpy()[0,3])
    yte.append(d.y.numpy())    
    lte.append(np.log10(len(d.x.numpy()))   ) 
yte=np.vstack(yte)

# %%
xtr, ytr, ltr = [], [], []
for d in train_data:
    xtr.append(d.x.numpy()[0,3])
    ytr.append(d.y.numpy())    
    ltr.append(np.log10(len(d.x.numpy()))   ) 
ytr=np.vstack(ytr)

# %%
bins=20
fig, ax = plt.subplots(3, figsize=(12,12))
ax[0].hist(xtr, bins=bins, histtype='step', density=1, label='train')
ax[0].hist(xte, bins=bins, histtype='step', density=1, label='test')
ax[0].set(xlabel='Final halo mass')

ax[1].hist(ytr, bins=bins, histtype='step', density=1, label='train')
ax[1].hist(yte, bins=bins, histtype='step', density=1, label='test')
ax[1].set(xlabel='Stellar mass')

ax[2].hist(ltr, bins=bins, histtype='step', density=1, label='train')
ax[2].hist(lte, bins=bins, histtype='step', density=1, label='test');
ax[2].set(xlabel='log10(Tree length)')

for a in ax:
    a.set(yscale='log')
    a.legend()
