# %%
import torch, pickle, time, os
import numpy as np
import matplotlib.pyplot as plt
import torch_geometric as tg
from torch_geometric.loader import DataLoader
# if torch.cuda.is_available():
#     from accelerate import Accelerator
#     accelerator = Accelerator()
#     device = accelerator.device
### accelerate huggingface to GPU

# %%
os.listdir('../../../../scratch/gpfs/cj1223/GraphStorage/')
# Out:
# ['medium_beforeafter',
#  'test_onlyhmass_smass',
#  'medium_all_q_diffbeforeafter',
#  'medium_all_smass',
#  'test_beforeafter',
#  'test_all_smass',
#  'transformers',
#  'medium_all_variance',
#  'medium_all_q',
#  'medium_all_final',
#  'test_variance',
#  'small_all_q_variancehalomass',
#  'medium_all_residual',
#  'medium_all',
#  'test',
#  'test_final',
#  'med_all_residual',
#  'one_all_q',
#  '105lim_all_smass',
#  'small_all_q']

# %%
# case='medium_all_q'
# case='105lim_all_smass'
# case='medium_all_residual'
case='medium_all_final'
data=pickle.load(open(f'../../../../scratch/gpfs/cj1223/GraphStorage/{case}/data.pkl', 'rb'))
print(len(data))
# Out:
# 20291

# %%
import torch.nn.functional as F
from torch.nn import Linear, BatchNorm1d, LayerNorm
from torch_geometric.nn import SAGEConv, global_mean_pool, norm, global_max_pool, global_add_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels, nlin=3):
        super(GCN, self).__init__()
        
        self.conv1 = SAGEConv(data[0].num_node_features, hidden_channels) ##use meta-layer
        ## https://pytorch-geometric.readthedocs.io/en/latest/modules/nn.html#torch_geometric.nn.meta.MetaLayer
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        
        # Our final linear layer will define our output
        self.norm = LayerNorm(normalized_shape=hidden_channels) # layer_norm instead
        self.lin1 = Linear(hidden_channels, 1)
        
    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
#         x = self.conv3(x, edge_index)   

          # 2. Readout layer
#         x = global_max_pool(x, batch)  ## Miles says use sumpool
#         x = global_mean_pool(x, batch)
#         x=concat(x1,x2)
        x = global_add_pool(x, batch)  ## Miles says use sumpool

#         x = F.dropout(x, p=0.1, training=self.training)

        x = self.lin1(self.norm(x))
#         x=self.lin1(x)
        return x
    
model = GCN(hidden_channels=32)
next(model.parameters()).is_cuda ##check number one
# Out:
# False

# %%
criterion = torch.nn.MSELoss()
n_epochs=10
batch_size=64
split=0.8
np.random.shuffle(data)
test_data=data[int(len(data)*split):]
train_data=data[:int(len(data)*split)]

# %%
train_loader=DataLoader(train_data, batch_size=batch_size, shuffle=1)
test_loader=DataLoader(test_data, batch_size=batch_size, shuffle=1)    
optimizer = torch.optim.Adam(model.parameters(), lr=0.003)
# _, _, test_loader = accelerator.prepare(model, optimizer, train_loader)
# model, optimizer, train_loader = accelerator.prepare(model, optimizer, train_loader)

# Initialize our train function
def train():
    model.train()
 
    for data in train_loader:  
        out = model(data.x, data.edge_index, data.batch)  
        loss = criterion(out, data.y.view(-1,1)) 
        loss.backward()
#         accelerator.backward(loss)
        optimizer.step() 
        optimizer.zero_grad() 
 # test function
def test(loader):
    model.eval()
 
    correct = 0
    for dat in loader: 
        out = model(dat.x, dat.edge_index, dat.batch) 
#         print(out)
        correct += (torch.square(out - dat.y.view(-1,1))).sum() 
    return correct / len(loader.dataset) 
tr_acc, te_acc=[],[]
start=time.time()
for epoch in range(n_epochs):
    train()
    
    if (epoch+1)%2==0:
        train_acc = test(train_loader).detach().numpy()
        test_acc = test(test_loader).detach().numpy()
        tr_acc.append(train_acc)
        te_acc.append(test_acc)
        print(f'Epoch: {epoch+1:03d}, Train scatter: {np.sqrt(train_acc):.4f}, Test scatter: {np.sqrt(test_acc):.4f}')
stop=time.time()
spent=stop-start
print(f"{spent:.2f} seconds spent training, {spent/n_epochs:.3f} seconds per epoch. Processed {len(data)*split*n_epochs/spent:.0f} trees per second")
# Out:
# Epoch: 002, Train scatter: 0.9533, Test scatter: 0.9470
# Epoch: 004, Train scatter: 0.9532, Test scatter: 0.9469
# Epoch: 006, Train scatter: 0.9553, Test scatter: 0.9491
# Epoch: 008, Train scatter: 0.9533, Test scatter: 0.9470
# Epoch: 010, Train scatter: 0.9541, Test scatter: 0.9478
# 36.18 seconds spent training, 3.618 seconds per epoch. Processed 4487 trees per second

# %%
plt.plot(tr_acc, label='train loss')
plt.plot(te_acc, label='test loss')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %%
ys, pred=[],[]
def test(loader):
    model.eval()
 
    correct = 0
    for dat in loader: 
        out = model(dat.x, dat.edge_index, dat.batch) 
        pred.append(out.view(1,-1).detach().numpy())
        ys.append(np.array(dat.y)) 
test(test_loader)
# test(train_loader)
ys=np.hstack(ys)
pred=np.hstack(pred)[0]

# %%
fig, ax= plt.subplots(2, figsize=(9,12))
bins=50
ax[0].hist(ys, bins=bins, range=(np.percentile(np.hstack([ys,pred]), [1,99])), label='true',  histtype='step')
ax[0].hist(pred, bins=bins, range=(np.percentile(np.hstack([ys,pred]), [1,99])), label='pred', histtype='step')
ax[1].hist((ys-pred), bins=bins,range=(np.percentile(ys-pred, [1,99])),  histtype='step', label='residuals');
ax[0].legend()
ax[1].legend()
ax[0].set(title='Predicted/true stellar mass', xlabel='log10(M_stellar)', ylabel='N')
ax[1].set(title=f'Residuals, scatter is {np.std(ys-pred):.2f}',
          xlabel='log10(M_stellar)_true-log10(M_stellar)_predicted', ylabel='N')
# Out:
# [Text(0.5, 1.0, 'Residuals, scatter is 0.95'),
#  Text(0.5, 0, 'log10(M_stellar)_true-log10(M_stellar)_predicted'),
#  Text(0, 0.5, 'N')]

# %%
fig, ax =plt.subplots(figsize=(12,9))
ax.plot(ys,pred, 'ro')
ax.plot([min(ys),max(ys)],[min(ys),max(ys)], 'k--', label='Perfect correspondance')
ax.set(xlabel='true',ylabel='predicted', title='True/predicted corr')
ax.legend()

# %%
fig, ax =plt.subplots(figsize=(12,9))
h = ax.hist2d(ys,pred, bins=50, range=[np.percentile(ys, [1,99]),np.percentile(pred, [1,99])])
fig.colorbar(h[3], ax=ax)
ax.plot([min(ys),max(ys)],[min(ys),max(ys)], 'k--', label='Perfect correspondance')
ax.set(xlabel='true',ylabel='predicted', title='True/predicted corr')
ax.legend()

# %%
x,y=[], []
for d in data:
    x.append(d.x[0].numpy())
    y.append(d.y.numpy())

# %%
plt.plot(x, y, 'o', markersize=1)

# %%
data
# Out:
# [Data(x=[1, 1], edge_index=[2, 1], y=-1.3058960437774658),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0867538452148438),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8981945514678955),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.791179895401001),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4413442611694336),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9585362672805786),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.4909144639968872),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1429505348205566),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6324875354766846),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6827914714813232),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8911374807357788),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7987695336341858),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5326716899871826),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2692500352859497),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9176347255706787),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.2996658384799957),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.443335771560669),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2293599843978882),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7255303859710693),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.023573875427246),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.852370023727417),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0897343158721924),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5085640549659729),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6977729797363281),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.649308204650879),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.018030235543847084),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.4755985736846924),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.32403111457824707),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6372820138931274),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1936938762664795),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9897551536560059),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5464844703674316),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.6369820833206177),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.182281255722046),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9051446914672852),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.0912482887506485),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6435878276824951),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0613927841186523),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9817406535148621),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1202207803726196),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.54264497756958),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3078557252883911),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5139352083206177),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5444319248199463),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0972363948822021),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.3228631019592285),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7337518334388733),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6235653758049011),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3217567205429077),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.566586971282959),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.7543246746063232),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.47220003604888916),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5555757284164429),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4300446510314941),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6044464707374573),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.47794198989868164),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9635108113288879),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7463881969451904),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.928364634513855),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.408717155456543),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2410662174224854),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.160426378250122),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0835328102111816),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.4393653869628906),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4047374725341797),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.645290493965149),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2317230701446533),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9773077368736267),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7218594551086426),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.2829686403274536),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5622937679290771),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.272338330745697),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3687368631362915),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.16346322000026703),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.9253564476966858),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.3440332412719727),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7005624175071716),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.202229380607605),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.167264461517334),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7092777490615845),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8970657587051392),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.4320307970046997),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6745294332504272),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.560831606388092),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7314313650131226),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.367027759552002),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3087797164916992),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9119277596473694),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.334153652191162),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.43129301071167),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4779824018478394),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.3265202045440674),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2949252128601074),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5456796884536743),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3323631286621094),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0707757472991943),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.12949976325035095),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.39933791756629944),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8963125944137573),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4342572689056396),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.08245982974767685),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5293381214141846),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.891587257385254),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.4818151891231537),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8041197061538696),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.5231075286865234),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5513322949409485),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.855126976966858),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9877661466598511),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.350770354270935),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1110470294952393),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6081037521362305),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.660387635231018),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8829774260520935),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.054237127304077),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3385896682739258),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.3892192840576172),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7731682062149048),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9175808429718018),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8579016327857971),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3787188529968262),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.557018756866455),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.13108229637146),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9630917906761169),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3670530319213867),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6530526876449585),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.2790141105651855),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4375464916229248),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.0770516395568848),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6474663019180298),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.3401551246643066),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.7639974355697632),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.871978998184204),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.021467447280884),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.7454323768615723),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0246771574020386),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.3683631420135498),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.0447591543197632),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5669137239456177),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.20568417012691498),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4522757530212402),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8343995809555054),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5638803243637085),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4668917655944824),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9999738931655884),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1630204916000366),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8846957683563232),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.4087333679199219),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6780558228492737),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.830651879310608),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.7696571350097656),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8328806161880493),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9485387802124023),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5208956003189087),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.326078176498413),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.3776802718639374),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6142597198486328),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5139777660369873),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.14576804637908936),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1791282892227173),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.878683090209961),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3242225646972656),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.406149983406067),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7457565069198608),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8146079778671265),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.1018118858337402),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.825091004371643),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.0373707115650177),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.2486719936132431),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0201950073242188),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.3826210498809814),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.1487913131713867),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.23092707991600037),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.46512845158576965),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8830735683441162),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.31234443187713623),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5454356670379639),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.4436299502849579),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3960040807724),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.551462173461914),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8710098266601562),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.041245460510254),
#  Data(x=[1, 1], edge_index=[2, 1], y=2.2236828804016113),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2554184198379517),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.6134327054023743),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.19074897468090057),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4060099124908447),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1083738803863525),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8156919479370117),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.237208843231201),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0295801162719727),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.5064657926559448),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.6465154886245728),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.988797664642334),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7100901007652283),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0723520517349243),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.880882740020752),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0539541244506836),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.3351042866706848),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.1569591760635376),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9757155179977417),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.4564419388771057),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.636237621307373),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8330284357070923),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7519384622573853),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9503788948059082),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3954769372940063),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.644897222518921),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.180500864982605),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.4093408584594727),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.1153206825256348),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9947036504745483),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6435744762420654),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8022509217262268),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.888282299041748),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1761952638626099),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.562518835067749),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9285856485366821),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.260546326637268),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5999284982681274),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1530866622924805),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4359532594680786),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.561312198638916),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7804285883903503),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2988786697387695),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.2562284767627716),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3929376602172852),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3812649250030518),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.03795609250664711),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2941508293151855),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.904792308807373),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1662429571151733),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5717825889587402),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0344079732894897),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8103524446487427),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4873409271240234),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.859586238861084),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.354433298110962),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8320213556289673),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8436750173568726),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9527992010116577),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6657493114471436),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9365615844726562),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0105559825897217),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9253115057945251),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.633433222770691),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7650729417800903),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0203938484191895),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.430148720741272),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.5610751509666443),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.402940273284912),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3860387802124023),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9013632535934448),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2212114334106445),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7610786557197571),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.713552474975586),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.064633846282959),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.15660971403121948),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5041685104370117),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6881338357925415),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0675323009490967),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3130671977996826),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.011345148086548),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3778274059295654),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.030482329428195953),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9470406770706177),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0696327686309814),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6522486209869385),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0004297494888306),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5899249315261841),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.104393482208252),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.7583531737327576),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3581640720367432),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.870358407497406),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.37924885749816895),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.471542239189148),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.735288381576538),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.067866563796997),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.14367355406284332),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6041111946105957),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3933886289596558),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6525645852088928),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2500203847885132),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9154987335205078),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.12135648727417),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.5371589660644531),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.6245347857475281),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5947339534759521),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.934061884880066),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.647477924823761),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.1383886337280273),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4316867589950562),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.97792649269104),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0787250995635986),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5404717922210693),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.3557318150997162),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.772532343864441),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4599872827529907),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.048586130142212),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0904247760772705),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.09190870821475983),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5403000116348267),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.4015892446041107),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3609310388565063),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2597194910049438),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.174985647201538),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4566658735275269),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.334917426109314),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.20148725807666779),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4792349338531494),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.1303241103887558),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5981860160827637),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.208950996398926),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.281312346458435),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6186448335647583),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5284134745597839),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.17499835789203644),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2619142532348633),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7770339250564575),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.794950008392334),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.022251009941101),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2615025043487549),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1819919347763062),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4703195095062256),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.1911120414733887),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5757735967636108),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9220654964447021),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4415806531906128),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7743444442749023),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.442643165588379),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9221308827400208),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4222015142440796),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.3108323812484741),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.1657402515411377),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.462676465511322),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.3193626403808594),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7423862218856812),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.74608314037323),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8564856052398682),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0020124912261963),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7665926218032837),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0316903591156006),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7144562005996704),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7548823356628418),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8962270617485046),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.13855530321598053),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0618692636489868),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.799379289150238),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9489015340805054),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.222538471221924),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.139216661453247),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9369820356369019),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.8225687742233276),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.292600154876709),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0021708011627197),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6581718921661377),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.041392207145691),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.2743145525455475),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0247336626052856),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.14832773804664612),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3111567497253418),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0623412132263184),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.10725068300962448),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1947581768035889),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7930688858032227),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8036856651306152),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.736856460571289),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.8923016786575317),
#  Data(x=[1, 1], edge_index=[2, 1], y=-3.0432002544403076),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3565404415130615),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0640132427215576),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.020716667175293),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9721328020095825),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9629442095756531),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.6441195011138916),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0583692789077759),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2839808464050293),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8759002685546875),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6074225902557373),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5086662769317627),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4522671699523926),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6777455806732178),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.213937520980835),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.435250997543335),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8152546882629395),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.21585647761821747),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9787734746932983),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.847690224647522),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.05645899102091789),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.766640841960907),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.24560396373271942),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.164093255996704),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8173229098320007),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.63416588306427),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5383769273757935),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6233117580413818),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0067273378372192),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2500505447387695),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8846591711044312),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.6836044192314148),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.150036096572876),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.914438247680664),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.54058039188385),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5506465435028076),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.65333890914917),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1373225450515747),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6104937195777893),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9325162172317505),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6985619068145752),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.5497387051582336),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8714876770973206),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7656674981117249),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5469845533370972),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8450194597244263),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4044122695922852),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3100467920303345),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0056371688842773),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7589892148971558),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.272313117980957),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.973912239074707),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9838947057723999),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.444685459136963),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.243749737739563),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.942611575126648),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9101266860961914),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8506639003753662),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6709338426589966),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.575242519378662),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5529800653457642),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.1935689449310303),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.3061482310295105),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.04925291985273361),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.623822808265686),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.8805729150772095),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1048786640167236),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3390614986419678),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.28161883354187),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3322147130966187),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.7720266580581665),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.4631121754646301),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6360422372817993),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.551551878452301),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7612816095352173),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.43781542778015137),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7412142753601074),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9425355195999146),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9908466935157776),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4660018682479858),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.784909963607788),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2900816202163696),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0939791202545166),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6648852825164795),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8000419735908508),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.144188404083252),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7698986530303955),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9565316438674927),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3191869258880615),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.4960446059703827),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2408627271652222),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3289077281951904),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3774802684783936),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.753582239151001),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3091591596603394),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7593234777450562),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.329817295074463),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7136108875274658),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7750890254974365),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6200096011161804),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7394063472747803),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.215566635131836),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.8663688898086548),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.47859251499176025),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.191239595413208),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5522390604019165),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6546204090118408),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2333284616470337),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2180027961730957),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.46531152725219727),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2895772457122803),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2809323072433472),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9298217296600342),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7503125667572021),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9372225403785706),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0290718078613281),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2961689233779907),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9927730560302734),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1121313571929932),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.38341841101646423),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.856928825378418),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4035810232162476),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2094320058822632),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9965696334838867),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8881731033325195),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.819638967514038),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.0010367254726588726),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.175685405731201),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.564270257949829),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2000250816345215),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6976885795593262),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6275427341461182),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9333721995353699),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2652385234832764),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.09118322283029556),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0177202224731445),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9522307515144348),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.022770557552576065),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9350256323814392),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4178820848464966),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2829456329345703),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.2716916799545288),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.637332797050476),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.49645498394966125),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.229975461959839),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.15873122215271),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.7306635975837708),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.2990472316741943),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8739043474197388),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.810742735862732),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.841905951499939),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9314950704574585),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.074765205383301),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.388000726699829),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9827829599380493),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.3955654799938202),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.568727970123291),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3324265480041504),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9232394695281982),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.610173225402832),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.778218150138855),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7360114455223083),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.693321943283081),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1443942785263062),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.3503894805908203),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7599702477455139),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.5183230638504028),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6999309062957764),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6708340644836426),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.10646915435791),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.71616530418396),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0862369537353516),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.1994500160217285),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9650388360023499),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6194849014282227),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5760810971260071),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5290238857269287),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.127866506576538),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8730475306510925),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3379414081573486),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.6224067807197571),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9920091032981873),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.639079213142395),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.3052588403224945),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.996849775314331),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.26920318603515625),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6560757160186768),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2203032970428467),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.060011863708496),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6147620677947998),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8762104511260986),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9682604074478149),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.63046133518219),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.044100761413574),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7095023393630981),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1186336278915405),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.35781753063201904),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.36281758546829224),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.003890872001648),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2296156883239746),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8969766497612),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9639942646026611),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.928946852684021),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.14370858669281),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.042575184255838394),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.5447016954421997),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.5562180280685425),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6874672174453735),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8263360261917114),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.323487401008606),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.36798545718193054),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.18723861873149872),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.1476719081401825),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9288547039031982),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.365619421005249),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7641308307647705),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.878495991230011),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4707660675048828),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5524636507034302),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.7662514448165894),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.3024413287639618),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.021139662712812424),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8314965963363647),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8551644086837769),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0382989645004272),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5767377614974976),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5249465703964233),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3694074153900146),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7772133350372314),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.29796430468559265),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.79905104637146),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.933327555656433),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.017904758453369),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.5144646167755127),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.018364906311035),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.8262154459953308),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5835691690444946),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0991971492767334),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9518885612487793),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.136931300163269),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.238891124725342),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9243910312652588),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.866007924079895),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.31629478931427),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2023953199386597),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7149853706359863),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.344256639480591),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.21405120193958282),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9821572303771973),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7358412146568298),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9791582822799683),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.471326231956482),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5300557613372803),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.1019630432128906),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2623636722564697),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3499947786331177),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.8181942105293274),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.39844176173210144),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.37322473526000977),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.901543140411377),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.6719980239868164),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.785262107849121),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9500845670700073),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8371608853340149),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3799805641174316),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.002328872680664),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.085148811340332),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.636147379875183),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.1477701663970947),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.286745548248291),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0378481149673462),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9595519304275513),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.08477997034788132),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.688207983970642),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.69643235206604),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2485908269882202),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8637932538986206),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6450622081756592),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.053091049194336),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.568884015083313),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8688595294952393),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3507440090179443),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.035936117172241),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9175126552581787),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.2683604657649994),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.995786190032959),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0226833820343018),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2685917615890503),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8998328447341919),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6743879318237305),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.1560816764831543),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1831120252609253),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.177551507949829),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8709097504615784),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3137069940567017),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5941774249076843),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.221966028213501),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7933522462844849),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.8775648474693298),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.384624481201172),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4724797010421753),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8673561811447144),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.4103742837905884),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8931769728660583),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9146344661712646),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1820738315582275),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0747054815292358),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.9838823676109314),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1619793176651),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5857237577438354),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8726359605789185),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.866981863975525),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.0512412786483765),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.1499698162078857),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.3440442979335785),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.2731570899486542),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.237194776535034),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8082361221313477),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.3353617787361145),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4073203802108765),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9512358903884888),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.783311665058136),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6181488037109375),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0279040336608887),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9797298908233643),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.610970377922058),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.374693751335144),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2161457538604736),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.2178075760602951),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4261865615844727),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0219852924346924),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7533881664276123),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1471346616744995),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5864152908325195),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9377528429031372),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0280022621154785),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.116085410118103),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.5502393841743469),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7329643964767456),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8956665992736816),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.6126670837402344),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5582200288772583),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1533455848693848),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.403099536895752),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9174982905387878),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3440954685211182),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.45323285460472107),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0340282917022705),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6542911529541016),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0202304124832153),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7777414321899414),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4781848192214966),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8308194875717163),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.058000326156616),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7219212055206299),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.8140137195587158),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0835270881652832),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.195852279663086),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.4310113787651062),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7072302103042603),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6134849786758423),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0928661823272705),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0366599559783936),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.10905668884515762),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7034071683883667),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6931676864624023),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.4281095564365387),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0637130737304688),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.3805621564388275),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9809460639953613),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5042614936828613),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6024754047393799),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.133176565170288),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0357789993286133),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.7607420682907104),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0422844886779785),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.848299264907837),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0594570636749268),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7948768734931946),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.749943733215332),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.09456467628479),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7419376373291016),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.5375301837921143),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9904428720474243),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.058457374572754),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.377129316329956),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.345873475074768),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5995155572891235),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6791269779205322),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.04718577116727829),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5396480560302734),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.851937472820282),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.085052728652954),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6160213351249695),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5740323066711426),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6859831809997559),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5526139736175537),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6989917755126953),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8389256000518799),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.15564213693141937),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.0305388905107975),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4831593036651611),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0373224020004272),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.0007028225809335709),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.1185524463653564),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9262633323669434),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.404966950416565),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2447564601898193),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2908504009246826),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5048317909240723),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3571616411209106),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.1721675395965576),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.088813066482544),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.257414698600769),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8756718635559082),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.301707148551941),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.540399432182312),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7097627520561218),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0458134412765503),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7517642974853516),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.0003125795046798885),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4925516843795776),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.097249984741211),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.729069709777832),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3150299787521362),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5535731315612793),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7848596572875977),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5867421627044678),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9214054346084595),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4066673517227173),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5299896001815796),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0018558502197266),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.6529344916343689),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3845897912979126),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7027255296707153),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2974135875701904),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2852805852890015),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.06080484017729759),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.311099886894226),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.4900102913379669),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9206703901290894),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3306422233581543),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9369182586669922),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.9821839332580566),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6817321181297302),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.097188711166382),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7214704751968384),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6737563610076904),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6921725273132324),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2307918071746826),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8359893560409546),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.36577990651130676),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7629742622375488),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.9719995260238647),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.326777219772339),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.332716226577759),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3171873092651367),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.8815558552742004),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.9918991327285767),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7539645433425903),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.46011871099472046),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.017083168029785),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.35239604115486145),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.102734327316284),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7342767715454102),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3328777551651),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.132347583770752),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7399262189865112),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.605303168296814),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.5400903820991516),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.1859516054391861),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7770158052444458),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9056057929992676),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4348856210708618),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.238201379776001),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.05905391648411751),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3629107475280762),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.15912485122680664),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3082212209701538),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0186567306518555),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0621652603149414),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8685160875320435),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0223124027252197),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.3582988977432251),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1827605962753296),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6784761548042297),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2431867122650146),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.36201420426368713),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6827747821807861),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.365442156791687),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.372328281402588),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7751381397247314),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.084718942642212),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.3811529874801636),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.29436457157135),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6439454555511475),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.9592608213424683),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9472099542617798),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.754489779472351),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3450499773025513),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6940492391586304),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.433337450027466),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2413098812103271),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.894656777381897),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0819822549819946),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7243454456329346),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2243480682373047),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.6626266241073608),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.100944757461548),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.234845757484436),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9972509741783142),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5666767358779907),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.11464273929595947),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.625763177871704),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.117210865020752),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9847660064697266),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2572929859161377),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4693470001220703),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.8214244246482849),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.933260440826416),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.785270094871521),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2968324422836304),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.02536678314209),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6544106006622314),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9281253814697266),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.766914963722229),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7896360158920288),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0991671085357666),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6625967025756836),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.6075922846794128),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9418017864227295),
#  Data(x=[1, 1], edge_index=[2, 1], y=2.249115228652954),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5853207111358643),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4156427383422852),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.1199417114257812),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.4048720896244049),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8827187418937683),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.03971940651535988),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8449981212615967),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.7151991724967957),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.4710999727249146),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.3616635203361511),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7721441388130188),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.5297638773918152),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.993666648864746),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.897562861442566),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3787001371383667),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3076131343841553),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1557608842849731),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.141117662191391),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5776219367980957),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7429745197296143),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3717745542526245),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9793487787246704),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6247462034225464),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8306871652603149),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7030147314071655),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5913140773773193),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.450848340988159),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2693872451782227),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8609083890914917),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2509102821350098),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.0103932619094849),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5496215224266052),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.692315697669983),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.920905590057373),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9085757732391357),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.5155279040336609),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6787537336349487),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2329250574111938),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7600476741790771),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.1380667686462402),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3804329633712769),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7464100122451782),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.748142957687378),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.19430752098560333),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.32693392038345337),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6632801294326782),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1807976961135864),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3524175882339478),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.978157639503479),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.7504568099975586),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.479280710220337),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9068655967712402),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8300728797912598),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.468807339668274),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6601253747940063),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.08703703433275223),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0194339752197266),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.4220462143421173),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.16234929859638214),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.0406651496887207),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8474456071853638),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5524775981903076),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0851097106933594),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9325720071792603),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8120254278182983),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8331260681152344),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1964459419250488),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.3900184631347656),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8128318786621094),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.30982163548469543),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8876597881317139),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.7803840637207031),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.4858575165271759),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.7335832118988037),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8918342590332031),
#  Data(x=[1, 1], edge_index=[2, 1], y=1.159903883934021),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.01753568649292),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.430492639541626),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.007946014404297),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.0609376430511475),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1579551696777344),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.2642239332199097),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9060672521591187),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8747009634971619),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8233387470245361),
#  Data(x=[1, 1], edge_index=[2, 1], y=0.2833419442176819),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8387278318405151),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.1829882860183716),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.8717138171195984),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.9081888794898987),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5296483039855957),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.9173868894577026),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.8530877828598022),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.804241418838501),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.5097029209136963),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.409644216299057),
#  Data(x=[1, 1], edge_index=[2, 1], y=-1.6240566968917847),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.531431198120117),
#  Data(x=[1, 1], edge_index=[2, 1], y=-0.42032840847969055),
#  Data(x=[1, 1], edge_index=[2, 1], y=-2.2255406379699707),
#  ...]

# %%
## remember to validate that test/val/train are actually comparable
## create toy problem (predict variance of all halo masses eg, verifying that in takes into account edges)
## same, predict average of the difference of post-merge halo and pre merger halos

## try different pools
