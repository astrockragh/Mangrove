# %%
import torch, pickle, time, os
import numpy as np
import matplotlib.pyplot as plt
import torch_geometric as tg
from torch_geometric.loader import DataLoader
# if torch.cuda.is_available():
#     from accelerate import Accelerator
#     accelerator = Accelerator()
#     device = accelerator.device
### accelerate huggingface to GPU

# %%
os.listdir('../../../../scratch/gpfs/cj1223/GraphStorage/')
# Out:
# ['medium_beforeafter',
#  'medium_all_q_diffbeforeafter',
#  'test_beforeafter',
#  'test_all_smass',
#  'transformers',
#  'medium_all_q',
#  'test_variance',
#  'small_all_q_variancehalomass',
#  'medium_all',
#  'test',
#  'one_all_q',
#  'small_all_q']

# %%
case='medium_all_q'
case='105lim_all_smass'
data=pickle.load(open(f'../../../../scratch/gpfs/cj1223/GraphStorage/{case}/data.pkl', 'rb'))

# %%
import torch.nn.functional as F
from torch.nn import Linear, BatchNorm1d
from torch_geometric.nn import SAGEConv, global_mean_pool, norm, global_max_pool, global_add_pool


class GCN(torch.nn.Module):
    def __init__(self, hidden_channels, nlin=3):
        super(GCN, self).__init__()
        
        self.conv1 = SAGEConv(data[0].num_node_features, hidden_channels) ##use meta-layer
        ## https://pytorch-geometric.readthedocs.io/en/latest/modules/nn.html#torch_geometric.nn.meta.MetaLayer
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        
        # Our final linear layer will define our output
        self.bn = BatchNorm1d(num_features=hidden_channels) # layer_norm instead
        self.lin1 = Linear(hidden_channels, 1)
        
    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
#         x = self.conv3(x, edge_index)   

          # 2. Readout layer
#         x = global_max_pool(x, batch)  ## Miles says use sumpool
#         x = global_mean_pool(x, batch)
#         x=concat(x1,x2)
        x = global_add_pool(x, batch)  ## Miles says use sumpool

#         x = F.dropout(x, p=0.1, training=self.training)

#         x = self.lin1(self.bn(x))
        x=self.lin1(x)
        return x
    
model = GCN(hidden_channels=32)
next(model.parameters()).is_cuda ##check number one
# Out:
# False

# %%
criterion = torch.nn.MSELoss()
n_epochs=100
batch_size=64
split=0.8
np.random.shuffle(data)
test_data=data[int(len(data)*split):]
train_data=data[:int(len(data)*split)]

# %%
train_loader=DataLoader(train_data, batch_size=batch_size, shuffle=1)
test_loader=DataLoader(test_data, batch_size=batch_size, shuffle=1)    
optimizer = torch.optim.Adam(model.parameters(), lr=0.003)
# _, _, test_loader = accelerator.prepare(model, optimizer, train_loader)
# model, optimizer, train_loader = accelerator.prepare(model, optimizer, train_loader)

# Initialize our train function
def train():
    model.train()
 
    for data in train_loader:  
        out = model(data.x, data.edge_index, data.batch)  
        loss = criterion(out, data.y.view(-1,1)) 
        loss.backward()
#         accelerator.backward(loss)
        optimizer.step() 
        optimizer.zero_grad() 
 # test function
def test(loader):
    model.eval()
 
    correct = 0
    for dat in loader: 
        out = model(dat.x, dat.edge_index, dat.batch) 
#         print(out)
        correct += (torch.square(out - dat.y.view(-1,1))).sum() 
    return correct / len(loader.dataset) 
tr_acc, te_acc=[],[]
start=time.time()
for epoch in range(n_epochs):
    train()
    
    if (epoch+1)%2==0:
        train_acc = test(train_loader).detach().numpy()
        test_acc = test(test_loader).detach().numpy()
        tr_acc.append(train_acc)
        te_acc.append(test_acc)
        print(f'Epoch: {epoch+1:03d}, Train scatter: {5*np.sqrt(train_acc):.4f}, Test scatter: {5*np.sqrt(test_acc):.4f}')
stop=time.time()
spent=stop-start
print(f"{spent:.2f} seconds spent training, {spent/n_epochs:.3f} seconds per epoch. Processed {len(data)*split*n_epochs/spent:.0f} trees per second")
# Out:
# Epoch: 002, Train scatter: 20.3940, Test scatter: 18.1037
# Epoch: 004, Train scatter: 40.0867, Test scatter: 34.8832
# Epoch: 006, Train scatter: 11.1897, Test scatter: 11.0462
# Epoch: 008, Train scatter: 8.3153, Test scatter: 8.4285
# Epoch: 010, Train scatter: 6.9877, Test scatter: 6.3769
# Epoch: 012, Train scatter: 8.9532, Test scatter: 7.1258
# Epoch: 014, Train scatter: 9.7415, Test scatter: 10.9299
# Epoch: 016, Train scatter: 7.6771, Test scatter: 6.7275
# Epoch: 018, Train scatter: 5.1673, Test scatter: 4.7993
# Epoch: 020, Train scatter: 7.9774, Test scatter: 7.0508
# Epoch: 022, Train scatter: 4.7925, Test scatter: 4.1452
# Epoch: 024, Train scatter: 20.4302, Test scatter: 17.2136
# Epoch: 026, Train scatter: 5.5719, Test scatter: 6.5214
# Epoch: 028, Train scatter: 14.4122, Test scatter: 13.8920
# Epoch: 030, Train scatter: 2.9237, Test scatter: 3.6066
# Epoch: 032, Train scatter: 2.5167, Test scatter: 2.6958
# Epoch: 034, Train scatter: 3.0909, Test scatter: 2.5852
# Epoch: 036, Train scatter: 3.3626, Test scatter: 2.8788
# Epoch: 038, Train scatter: 8.2167, Test scatter: 8.4302
# Epoch: 040, Train scatter: 7.1058, Test scatter: 5.9018
# Epoch: 042, Train scatter: 3.6385, Test scatter: 4.2157
# Epoch: 044, Train scatter: 2.5244, Test scatter: 2.8877
# Epoch: 046, Train scatter: 1.9464, Test scatter: 2.3033
# Epoch: 048, Train scatter: 2.3966, Test scatter: 2.2674
# Epoch: 050, Train scatter: 2.9461, Test scatter: 3.3777
# Epoch: 052, Train scatter: 8.4818, Test scatter: 7.4319
# Epoch: 054, Train scatter: 1.8546, Test scatter: 2.0278
# Epoch: 056, Train scatter: 1.6886, Test scatter: 1.7471
# Epoch: 058, Train scatter: 4.0174, Test scatter: 4.0676
# Epoch: 060, Train scatter: 1.4960, Test scatter: 1.7036
# Epoch: 062, Train scatter: 1.7892, Test scatter: 1.7323
# Epoch: 064, Train scatter: 3.5586, Test scatter: 3.6099
# Epoch: 066, Train scatter: 1.4650, Test scatter: 1.5749
# Epoch: 068, Train scatter: 2.0515, Test scatter: 1.8913
# Epoch: 070, Train scatter: 1.6903, Test scatter: 1.6968
# Epoch: 072, Train scatter: 1.3005, Test scatter: 1.3292
# Epoch: 074, Train scatter: 1.5248, Test scatter: 1.5277
# Epoch: 076, Train scatter: 2.2828, Test scatter: 2.1510
# Epoch: 078, Train scatter: 1.2961, Test scatter: 1.2447
# Epoch: 080, Train scatter: 1.3520, Test scatter: 1.2984
# Epoch: 082, Train scatter: 1.6999, Test scatter: 1.4854
# Epoch: 084, Train scatter: 1.2111, Test scatter: 1.1259
# Epoch: 086, Train scatter: 1.0886, Test scatter: 1.0767
# Epoch: 088, Train scatter: 1.2085, Test scatter: 1.1237
# Epoch: 090, Train scatter: 1.2044, Test scatter: 1.0716
# Epoch: 092, Train scatter: 1.0175, Test scatter: 1.0147
# Epoch: 094, Train scatter: 0.9621, Test scatter: 0.9817
# Epoch: 096, Train scatter: 1.0084, Test scatter: 1.0083
# Epoch: 098, Train scatter: 0.9316, Test scatter: 0.9462
# Epoch: 100, Train scatter: 0.9009, Test scatter: 0.9151
# 802.92 seconds spent training, 8.029 seconds per epoch. Processed 920 trees per second

# %%
plt.plot(tr_acc, label='train loss')
plt.plot(te_acc, label='test loss')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %%
ys, pred=[],[]
def test(loader):
    model.eval()
 
    correct = 0
    for dat in loader: 
        out = model(dat.x, dat.edge_index, dat.batch) 
        pred.append(5*out.view(1,-1).detach().numpy())
        ys.append(5*np.array(dat.y)) 
test(test_loader)
# test(train_loader)
ys=np.hstack(ys)
pred=np.hstack(pred)[0]

# %%
fig, ax= plt.subplots(2, figsize=(9,12))
bins=50
ax[0].hist(ys, bins=bins, range=(np.min(np.hstack([ys,pred]))/1.5,np.max(np.hstack([ys,pred]))/1.5), label='true',  histtype='step')
ax[0].hist(pred, bins=bins, range=(np.min(np.hstack([ys,pred]))/1.5,np.max(np.hstack([ys,pred]))/1.5), label='pred', histtype='step')
ax[1].hist((ys-pred), bins=bins,range=(np.min((ys-pred))/1.5,np.max((ys-pred))/1.5),  histtype='step', label='residuals');
ax[0].legend()
ax[1].legend()
ax[0].set(title='Predicted/true stellar mass')
ax[1].set(title=f'Residuals, scatter is {np.std(ys-pred):.2f}', xlabel='log M_*')
# Out:
# [Text(0.5, 1.0, 'Residuals, scatter is 0.91'), Text(0.5, 0, 'log M_*')]

# %%
fig, ax =plt.subplots(figsize=(12,9))
ax.plot(ys,pred, 'ro')
ax.plot([min(ys),max(ys)],[min(ys),max(ys)], 'k--', label='Perfect correspondance')
ax.set(xlabel='true',ylabel='predicted', title='True/predicted corr')
ax.legend()

# %%
x,y=[], []
for d in data:
    x.append(d.x[0,3].numpy())
    y.append(d.y.numpy())

# %%
plt.plot(x, y, 'o', markersize=1)

# %%
## remember to validate that test/val/train are actually comparable
## create toy problem (predict variance of all halo masses eg, verifying that in takes into account edges)
## same, predict average of the difference of post-merge halo and pre merger halos

## try different pools
